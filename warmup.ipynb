# %% [markdown]
# # Data Integrity Check

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/sales_transactions.csv')

# %%
#Shape
rows, cols = df.shape

print(f'Rows: {rows}')
print(f'Cols: {cols}')
# Out:
# Rows: 12
# Cols: 7

# %%
#Head
print(df.head())
# Out:
#    account           name  order       sku  quantity  unit price  ext price
# 0   383080       Will LLC  10001  B1-20000         7       33.69     235.83
# 1   383080       Will LLC  10001  S1-27722        11       21.12     232.32
# 2   383080       Will LLC  10001  B1-86481         3       35.99     107.97
# 3   412290  Jerde-Hilpert  10005  S1-06532        48       55.82    2679.36
# 4   412290  Jerde-Hilpert  10005  S1-82801        21       13.62     286.02

# %%
# Bottom 5
print(df.tail())
# Out:
#     account           name  order       sku  quantity  unit price  ext price
# 7    412290  Jerde-Hilpert  10005  S1-27722        36       25.42     915.12
# 8    218895      Kulas Inc  10006  S1-27722        32       95.66    3061.12
# 9    218895      Kulas Inc  10006  B1-33087        23       22.55     518.65
# 10   218895      Kulas Inc  10006  B1-33364         3       72.30     216.90
# 11   218895      Kulas Inc  10006  B1-20000        -1       72.18     -72.18

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   account     12 non-null     int64
#  1   name        12 non-null     str
#  2   order       12 non-null     int64
#  3   sku         12 non-null     str
#  4   quantity    12 non-null     int64
#  5   unit price  12 non-null     float64
#  6   ext price   12 non-null     float64
# dtypes: float64(2), int64(3), str(2)
# memory usage: 804.0 bytes
# None

# %%
# Describe()
print(df.describe(include='all'))
# Out:
#               account           name         order       sku   quantity  \
# count       12.000000             12     12.000000        12  12.000000
# unique            NaN              3           NaN         8        NaN
# top               NaN  Jerde-Hilpert           NaN  S1-27722        NaN
# freq              NaN              5           NaN         3        NaN
# mean    340522.500000            NaN  10004.333333       NaN  19.666667
# std      90633.772416            NaN      2.059715       NaN  16.945546
# min     218895.000000            NaN  10001.000000       NaN  -1.000000
# 25%     218895.000000            NaN  10004.000000       NaN   6.000000
# 50%     383080.000000            NaN  10005.000000       NaN  16.000000
# 75%     412290.000000            NaN  10006.000000       NaN  33.000000
# max     412290.000000            NaN  10006.000000       NaN  48.000000
#
#         unit price    ext price
# count    12.000000    12.000000
# unique         NaN          NaN
# top            NaN          NaN
# freq           NaN          NaN
# mean     51.650833  1040.508333
# std      29.694003  1267.357787
# min      13.620000   -72.180000
# 25%      24.702500   228.465000
# 50%      45.905000   402.335000
# 75%      73.952500  1356.180000
# max      95.660000  3472.040000

# %%
print('Missing Values: ')
print(df.isnull().sum())
# Out:
# Missing Values:
# account       0
# name          0
# order         0
# sku           0
# quantity      0
# unit price    0
# ext price     0
# dtype: int64

# %%
# check for dupes
print(f'Num of duplicate rows: {df.duplicated().sum()}')
# Out:
# Num of duplicate rows: 0
